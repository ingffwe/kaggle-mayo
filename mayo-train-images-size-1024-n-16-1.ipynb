# %% [markdown]
# # Library

# %%
# !conda install -y --channel conda-forge pyvips
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - pyvips
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boost-cpp-1.74.0           |       h312852a_4        16.3 MB  conda-forge
#     cfitsio-4.0.0              |       h9a35b8e_0         1.3 MB  conda-forge
#     glib-2.72.1                |       h6239696_0         443 KB  conda-forge
#     glib-tools-2.72.1          |       h6239696_0         107 KB  conda-forge
#     gstreamer-orc-0.4.32       |       h7f98852_1         267 KB  conda-forge
#     hdf5-1.12.1                |nompi_h2386368_104         3.5 MB  conda-forge
#     libexif-0.6.21             |       h7f98852_0         992 KB  conda-forge
#     libglib-2.72.1             |       h2d90d5f_0         3.1 MB  conda-forge
#     libgsf-1.14.49             |       he99f2b3_0         455 KB  conda-forge
#     libmatio-1.5.21            |       hdf44fe6_1         285 KB  conda-forge
#     libvips-8.12.2             |       hbb474f9_0         3.7 MB  conda-forge
#     libzlib-1.2.12             |       h166bdaf_1          63 KB  conda-forge
#     nspr-4.32                  |       h9c3ff4c_1         233 KB  conda-forge
#     nss-3.78                   |       h2350873_0         2.1 MB  conda-forge
#     openslide-3.4.1            |       h978ee9a_4         114 KB  conda-forge
#     openssl-1.1.1q             |       h166bdaf_0         2.1 MB  conda-forge
#     pkgconfig-1.5.5            |   py37h89c1867_2          13 KB  conda-forge
#     poppler-22.01.0            |       h1434ded_2        18.2 MB  conda-forge
#     poppler-data-0.4.11        |       hd8ed1ab_0         3.6 MB  conda-forge
#     pyvips-2.2.0               |   py37had655be_0         110 KB  conda-forge
#     zlib-1.2.12                |       h166bdaf_1          91 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        57.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.74.0-h312852a_4
#   cfitsio            conda-forge/linux-64::cfitsio-4.0.0-h9a35b8e_0
#   glib               conda-forge/linux-64::glib-2.72.1-h6239696_0
#   glib-tools         conda-forge/linux-64::glib-tools-2.72.1-h6239696_0
#   gstreamer-orc      conda-forge/linux-64::gstreamer-orc-0.4.32-h7f98852_1
#   hdf5               conda-forge/linux-64::hdf5-1.12.1-nompi_h2386368_104
#   libexif            conda-forge/linux-64::libexif-0.6.21-h7f98852_0
#   libgsf             conda-forge/linux-64::libgsf-1.14.49-he99f2b3_0
#   libmatio           conda-forge/linux-64::libmatio-1.5.21-hdf44fe6_1
#   libvips            conda-forge/linux-64::libvips-8.12.2-hbb474f9_0
#   nspr               conda-forge/linux-64::nspr-4.32-h9c3ff4c_1
#   nss                conda-forge/linux-64::nss-3.78-h2350873_0
#   openslide          conda-forge/linux-64::openslide-3.4.1-h978ee9a_4
#   pkgconfig          conda-forge/linux-64::pkgconfig-1.5.5-py37h89c1867_2
#   poppler            conda-forge/linux-64::poppler-22.01.0-h1434ded_2
#   poppler-data       conda-forge/noarch::poppler-data-0.4.11-hd8ed1ab_0
#   pyvips             conda-forge/linux-64::pyvips-2.2.0-py37had655be_0
#
# The following packages will be UPDATED:
#
#   libglib                                 2.70.2-h174f98d_4 --> 2.72.1-h2d90d5f_0
#   libzlib                              1.2.11-h166bdaf_1014 --> 1.2.12-h166bdaf_1
#   openssl                                 1.1.1o-h166bdaf_0 --> 1.1.1q-h166bdaf_0
#   zlib                                 1.2.11-h166bdaf_1014 --> 1.2.12-h166bdaf_1
#
#
#
# Downloading and Extracting Packages
# zlib-1.2.12          | 91 KB     | ##################################### | 100%
# pyvips-2.2.0         | 110 KB    | ##################################### | 100%
# hdf5-1.12.1          | 3.5 MB    | ##################################### | 100%
# pkgconfig-1.5.5      | 13 KB     | ##################################### | 100%
# libgsf-1.14.49       | 455 KB    | ##################################### | 100%
# boost-cpp-1.74.0     | 16.3 MB   | ##################################### | 100%
# libglib-2.72.1       | 3.1 MB    | ##################################### | 100%
# openssl-1.1.1q       | 2.1 MB    | ##################################### | 100%
# libexif-0.6.21       | 992 KB    | ##################################### | 100%
# libvips-8.12.2       | 3.7 MB    | ##################################### | 100%
# glib-2.72.1          | 443 KB    | ##################################### | 100%
# cfitsio-4.0.0        | 1.3 MB    | ##################################### | 100%
# nspr-4.32            | 233 KB    | ##################################### | 100%
# poppler-22.01.0      | 18.2 MB   | ##################################### | 100%
# gstreamer-orc-0.4.32 | 267 KB    | ##################################### | 100%
# poppler-data-0.4.11  | 3.6 MB    | ##################################### | 100%
# glib-tools-2.72.1    | 107 KB    | ##################################### | 100%
# libmatio-1.5.21      | 285 KB    | ##################################### | 100%
# nss-3.78             | 2.1 MB    | ##################################### | 100%
# libzlib-1.2.12       | 63 KB     | ##################################### | 100%
# openslide-3.4.1      | 114 KB    | ##################################### | 100%
# done
# done
# done

# %%
import os
import gc
import zipfile

import numpy as np
import pandas as pd
from tqdm.auto import tqdm

import cv2
import pyvips
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File W:\Anaconda3\envs\UWMGI39\lib\site-packages\pyvips\__init__.py:19, in <module>
#      18 try:
# ---> 19     import _libvips
#      21     logger.debug('Loaded binary module _libvips')
#
# ModuleNotFoundError: No module named '_libvips'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Input In [1], in <cell line: 10>()
#       7 from tqdm.auto import tqdm
#       9 import cv2
# ---> 10 import pyvips
#
# File W:\Anaconda3\envs\UWMGI39\lib\site-packages\pyvips\__init__.py:70, in <module>
#      67     _gobject_libname = 'libgobject-2.0.so.0'
#      69 # possibly use ctypes.util.find_library() to locate the lib?
# ---> 70 gobject_lib = ffi.dlopen(_gobject_libname)
#      71 vips_lib = ffi.dlopen(_vips_libname)
#      72 if _glib_libname:
#
# File W:\Anaconda3\envs\UWMGI39\lib\site-packages\cffi\api.py:150, in FFI.dlopen(self, name, flags)
#     147     raise TypeError("dlopen(name): name must be a file name, None, "
#     148                     "or an already-opened 'void *' handle")
#     149 with self._lock:
# --> 150     lib, function_cache = _make_ffi_library(self, name, flags)
#     151     self._function_caches.append(function_cache)
#     152     self._libraries.append(lib)
#
# File W:\Anaconda3\envs\UWMGI39\lib\site-packages\cffi\api.py:832, in _make_ffi_library(ffi, libname, flags)
#     830 def _make_ffi_library(ffi, libname, flags):
#     831     backend = ffi._backend
# --> 832     backendlib = _load_backend_lib(backend, libname, flags)
#     833     #
#     834     def accessor_function(name):
#
# File W:\Anaconda3\envs\UWMGI39\lib\site-packages\cffi\api.py:827, in _load_backend_lib(backend, name, flags)
#     825     if first_error is not None:
#     826         msg = "%s.  Additionally, %s" % (first_error, msg)
# --> 827     raise OSError(msg)
#     828 return backend.load_library(path, flags)
#
# OSError: cannot load library 'libgobject-2.0-0.dll': error 0x7e.  Additionally, ctypes.util.find_library() did not manage to locate a library called 'libgobject-2.0-0.dll'

# %% [markdown]
# # Data Load

# %%
train = pd.read_csv('../input/mayo-clinic-strip-ai/train.csv')
other = pd.read_csv('../input/mayo-clinic-strip-ai/other.csv')
test = pd.read_csv('../input/mayo-clinic-strip-ai/test.csv')
submission = pd.read_csv('../input/mayo-clinic-strip-ai/sample_submission.csv')

# print(train.shape)
# display(train.head())
# print(other.shape)
# display(other.head())
# print(test.shape)
# display(test.head())
# print(submission.shape)
# display(submission.head())
# Out:
# (754, 5)
#    image_id  center_id patient_id  image_num label
# 0  006388_0         11     006388          0    CE
# 1  008e5c_0         11     008e5c          0    CE
# 2  00c058_0         11     00c058          0   LAA
# 3  01adc5_0         11     01adc5          0   LAA
# 4  026c97_0          4     026c97          0    CE
# (396, 5)
#    image_id patient_id  image_num  other_specified    label
# 0  01f2b3_0     01f2b3          0              NaN  Unknown
# 1  01f2b3_1     01f2b3          1              NaN  Unknown
# 2  02ebd5_0     02ebd5          0              NaN  Unknown
# 3  0412ab_0     0412ab          0              NaN  Unknown
# 4  04414e_0     04414e          0  Hypercoagulable    Other
# (4, 4)
#    image_id  center_id patient_id  image_num
# 0  006388_0         11     006388          0
# 1  008e5c_0         11     008e5c          0
# 2  00c058_0         11     00c058          0
# 3  01adc5_0         11     01adc5          0
# (4, 3)
#   patient_id   CE  LAA
# 0     006388  0.5  0.5
# 1     008e5c  0.5  0.5
# 2     00c058  0.5  0.5
# 3     01adc5  0.5  0.5

# %% [markdown]
# # Prepare dataset

# %% [markdown]
# Images are very large, so tile method that worked [previous competition](https://www.kaggle.com/competitions/prostate-cancer-grade-assessment/discussion/146855) would be effective.

# %%
def tile(img, sz=128, N=16):
    shape = img.shape
    pad0,pad1 = (sz - shape[0]%sz)%sz, (sz - shape[1]%sz)%sz
    img = np.pad(img,[[pad0//2,pad0-pad0//2],[pad1//2,pad1-pad1//2],[0,0]],constant_values=255)
    img = img.reshape(img.shape[0]//sz,sz,img.shape[1]//sz,sz,3)
    img = img.transpose(0,2,1,3,4).reshape(-1,sz,sz,3)
    if len(img) < N:
        img = np.pad(img,[[0,N-len(img)],[0,0],[0,0],[0,0]],constant_values=255)
    idxs = np.argsort(img.reshape(img.shape[0],-1).sum(-1))[:N]
    img = img[idxs]
    return img

# %%
def save_dataset(
    df: pd.DataFrame, 
    N=16,
    max_size=20000, 
    crop_size=1024, 
    image_dir='../input/mayo-clinic-strip-ai/train', 
    out_dir='train_images.zip',
):
    format_to_dtype = {
       'uchar': np.uint8,
       'char': np.int8,
       'ushort': np.uint16,
       'short': np.int16,
       'uint': np.uint32,
       'int': np.int32,
       'float': np.float32,
       'double': np.float64,
       'complex': np.complex64,
       'dpcomplex': np.complex128,
    }
    def vips2numpy(vi):
        return np.ndarray(
            buffer=vi.write_to_memory(),
            dtype=format_to_dtype[vi.format],
            shape=[vi.height, vi.width, vi.bands])
    with zipfile.ZipFile(out_dir, "w") as out_image:
        tk0 = tqdm(enumerate(df["image_id"].values), total=len(df))
        for i, image_id in tk0:
            print(f"[{i+1}/{len(df)}] image_id: {image_id}")
            image = pyvips.Image.thumbnail(f'{image_dir}/{image_id}.tif', max_size)
            image = vips2numpy(image)
            width, height, c = image.shape
            print(f"Input width: {width} height: {height}")
            images = tile(image, sz=crop_size, N=N)
            for idx, img in enumerate(images):
                img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
                img = cv2.imencode(".jpg", img, [cv2.IMWRITE_JPEG_QUALITY, 100])[1]
                out_image.writestr(f"{image_id}_{idx}.jpg", img)
            del img, image, images; gc.collect()

i = 1 # 1~8

if i == 8:
    df = train[(i-1)*100:]
else:
    df = train[(i-1)*100:i*100]

save_dataset(
    df,
    N=16, 
    max_size=20000,
    crop_size=1024, 
    image_dir='../input/mayo-clinic-strip-ai/train', 
    out_dir=f'train_images_{i}.zip'
)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# [1/100] image_id: 006388_0
# Input width: 20000 height: 11187
# [2/100] image_id: 008e5c_0
# Input width: 20000 height: 4005
# [3/100] image_id: 00c058_0
# Input width: 20000 height: 4937
# [4/100] image_id: 01adc5_0
# Input width: 9512 height: 20000
# [5/100] image_id: 026c97_0
# Input width: 15697 height: 20000
# [6/100] image_id: 028989_0
# Input width: 20000 height: 7653
# [7/100] image_id: 029c68_0
# Input width: 20000 height: 19391
# [8/100] image_id: 032f10_0
# Input width: 20000 height: 4606
# [9/100] image_id: 0372b0_0
# Input width: 20000 height: 3852
# [10/100] image_id: 037300_0
# Input width: 20000 height: 7707
# [11/100] image_id: 03d1ec_0
# Input width: 20000 height: 15203
# [12/100] image_id: 03e6b7_0
# Input width: 20000 height: 7292
# [13/100] image_id: 0415c3_0
# Input width: 20000 height: 5176
# [14/100] image_id: 04439c_0
# Input width: 20000 height: 9406
# [15/100] image_id: 045eb0_0
# Input width: 20000 height: 9406
# [16/100] image_id: 0468a8_0
# Input width: 20000 height: 9615
# [17/100] image_id: 0468a8_1
# Input width: 20000 height: 17380
# [18/100] image_id: 049194_0
# Input width: 20000 height: 19798
# [19/100] image_id: 049194_1
# Input width: 20000 height: 9087
# [20/100] image_id: 04f7a4_0
# Input width: 20000 height: 8501
# [21/100] image_id: 055f6a_0
# Input width: 20000 height: 7584
# [22/100] image_id: 05a1ec_0
# Input width: 20000 height: 12556
# [23/100] image_id: 062387_0
# Input width: 20000 height: 6149
# [24/100] image_id: 070fe0_0
# Input width: 20000 height: 14804
# [25/100] image_id: 08d3d8_0
# Input width: 20000 height: 15486
# [26/100] image_id: 09644e_0
# Input width: 20000 height: 6928
# [27/100] image_id: 09644e_1
# Input width: 20000 height: 8992
# [28/100] image_id: 09644e_2
# Input width: 20000 height: 12291
# [29/100] image_id: 09644e_3
# Input width: 20000 height: 10133
# [30/100] image_id: 09644e_4
# Input width: 20000 height: 7154
# [31/100] image_id: 098f15_0
# Input width: 15822 height: 20000
# [32/100] image_id: 0a3ad1_0
# Input width: 20000 height: 13065
# [33/100] image_id: 0a47c9_0
# Input width: 20000 height: 17716
# [34/100] image_id: 0aaeb3_0
# Input width: 18803 height: 20000
# [35/100] image_id: 0aff58_0
# Input width: 20000 height: 6230
# [36/100] image_id: 0b25f8_0
# Input width: 20000 height: 8373
# [37/100] image_id: 0b7871_0
# Input width: 20000 height: 19135
# [38/100] image_id: 0b7871_1
# Input width: 20000 height: 15264
# [39/100] image_id: 0b7cc8_0
# Input width: 18373 height: 20000
# [40/100] image_id: 0ba49d_0
# Input width: 20000 height: 6187
# [41/100] image_id: 0bd414_0
# Input width: 20000 height: 8371
# [42/100] image_id: 0bddf9_0
# Input width: 5913 height: 20000
# [43/100] image_id: 0c60b8_0
# Input width: 20000 height: 11353
# [44/100] image_id: 0cc0bc_0
# Input width: 20000 height: 14745
# [45/100] image_id: 0d4164_0
# Input width: 20000 height: 19567
# [46/100] image_id: 0d533f_0
# Input width: 9982 height: 20000
# [47/100] image_id: 0d718a_0
# Input width: 4726 height: 20000
# [48/100] image_id: 0d93ce_0
# Input width: 11165 height: 20000
# [49/100] image_id: 0df5f8_0
# Input width: 20000 height: 10391
# [50/100] image_id: 0e4dac_0
# Input width: 10455 height: 20000
# [51/100] image_id: 0e696a_0
# Input width: 20000 height: 8555
# [52/100] image_id: 0e696a_1
# Input width: 20000 height: 13942
# [53/100] image_id: 0ed87f_0
# Input width: 20000 height: 6564
# [54/100] image_id: 0ed87f_1
# Input width: 20000 height: 9724
# [55/100] image_id: 0ee750_0
# Input width: 20000 height: 10470
# [56/100] image_id: 0ee750_1
# Input width: 20000 height: 10222
# [57/100] image_id: 0f2961_0
# Input width: 20000 height: 5820
# [58/100] image_id: 0fcfe9_0
# Input width: 18573 height: 20000
# [59/100] image_id: 0ff6fc_0
# Input width: 20000 height: 9641
# [60/100] image_id: 0ff890_0
# Input width: 20000 height: 5594
# [61/100] image_id: 112b6e_0
# Input width: 15365 height: 20000
# [62/100] image_id: 112b6e_1
# Input width: 20000 height: 10585
# [63/100] image_id: 113bb3_0
# Input width: 20000 height: 3561
# [64/100] image_id: 129102_0
# Input width: 20000 height: 11434
# [65/100] image_id: 1295bb_0
# Input width: 20000 height: 6119
# [66/100] image_id: 12c8c9_0
# Input width: 20000 height: 11951
# [67/100] image_id: 13f372_0
# Input width: 7658 height: 20000
# [68/100] image_id: 140d1a_0
# Input width: 20000 height: 2672
# [69/100] image_id: 14d2fa_0
# Input width: 20000 height: 10458
# [70/100] image_id: 15aab4_0
# Input width: 13924 height: 20000
# [71/100] image_id: 15de51_0
# Input width: 16705 height: 20000
# [72/100] image_id: 162cad_0
# Input width: 20000 height: 8611
# [73/100] image_id: 1764ff_0
# Input width: 15772 height: 20000
# [74/100] image_id: 194e3f_0
# Input width: 20000 height: 7944
# [75/100] image_id: 19b036_0
# Input width: 20000 height: 10008
# [76/100] image_id: 19b036_1
# Input width: 20000 height: 6394
# [77/100] image_id: 19dd95_0
# Input width: 20000 height: 4186
# [78/100] image_id: 1a2e9e_0
# Input width: 20000 height: 13724
# [79/100] image_id: 1b86c5_0
# Input width: 20000 height: 7953
# [80/100] image_id: 1bbcba_0
# Input width: 20000 height: 6884
# [81/100] image_id: 1d0518_0
# Input width: 20000 height: 18398
# [82/100] image_id: 1d1bf0_0
# Input width: 20000 height: 10309
# [83/100] image_id: 1d5335_0
# Input width: 20000 height: 9119
# [84/100] image_id: 1d6d4f_0
# Input width: 20000 height: 9077
# [85/100] image_id: 1db82d_0
# Input width: 20000 height: 10037
# [86/100] image_id: 1db82d_1
# Input width: 20000 height: 8346
# [87/100] image_id: 1ec69e_0
# Input width: 20000 height: 7778
# [88/100] image_id: 1ef6da_0
# Input width: 20000 height: 8916
# [89/100] image_id: 1f018f_0
# Input width: 20000 height: 5189
# [90/100] image_id: 1f9d4f_0
# Input width: 20000 height: 7824
# [91/100] image_id: 1f9d4f_1
# Input width: 20000 height: 8742
# [92/100] image_id: 1fe0c4_0
# Input width: 20000 height: 8943
# [93/100] image_id: 1ffc5d_0
# Input width: 20000 height: 6548
# [94/100] image_id: 205025_0
# Input width: 12298 height: 20000
# [95/100] image_id: 20914b_0
# Input width: 11492 height: 20000
# [96/100] image_id: 20d5cf_0
# Input width: 20000 height: 8845
# [97/100] image_id: 214cfa_0
# Input width: 20000 height: 11264
# [98/100] image_id: 214cfa_1
# Input width: 20000 height: 5386
# [99/100] image_id: 21726e_0
# Input width: 20000 height: 14002
# [100/100] image_id: 217b27_0
# Input width: 20000 height: 5432
